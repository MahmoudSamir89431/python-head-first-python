# %%
import swimclub

# %%
swimclub.read_swim_data("Darius-13-100m-Fly.txt")
# Out:
# ('Darius',
#  '13',
#  '100m',
#  'Fly',
#  ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#  '1:26.58')

# %%
data = swimclub.read_swim_data("Darius-13-100m-Fly.txt")

# %%
time = [data]
time
# Out:
# [('Darius',
#   '13',
#   '100m',
#   'Fly',
#   ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#   '1:26.58')]

# %%
times = data[4]
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
swimer,age,distace,stroke,time2,average = data

# %%
import os

# %%
swim_files = os.listdir(swimclub.FOLDER)

# %%
len(swim_files)
# Out:
# 61

# %%
print(sorted(swim_files))
# Out:
# ['.DS_Store', 'Abi-10-100m-Back.txt', 'Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt', 'Ali-12-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Alison-14-100m-Breast.txt', 'Alison-14-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Bill-18-100m-Back.txt', 'Bill-18-200m-Back.txt', 'Blake-15-100m-Back.txt', 'Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt', 'Carl-15-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Chris-17-100m-Breast.txt', 'Darius-13-100m-Back.txt', 'Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt', 'Dave-17-100m-Free.txt', 'Dave-17-200m-Back.txt', 'Elba-14-100m-Free.txt', 'Emma-13-100m-Breast.txt', 'Emma-13-100m-Free.txt', 'Erika-15-100m-Breast.txt', 'Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt', 'Hannah-13-100m-Back.txt', 'Hannah-13-100m-Free.txt', 'Katie-9-100m-Back.txt', 'Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie-9-50m-Back.txt', 'Katie-9-50m-Breast.txt', 'Katie-9-50m-Fly.txt', 'Katie-9-50m-Free.txt', 'Lizzie-14-100m-Back.txt', 'Lizzie-14-100m-Free.txt', 'Maria-9-50m-Free.txt', 'Mike-15-100m-Back.txt', 'Mike-15-100m-Fly.txt', 'Mike-15-100m-Free.txt', 'Mike-15-200m-Free.txt', 'Mike-15-200m-IM.txt', 'Owen-15-100m-Free.txt', 'Ruth-13-100m-Back.txt', 'Ruth-13-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Ruth-13-200m-Free.txt', 'Ruth-13-400m-Free.txt', 'Tasmin-15-100m-Back.txt', 'Tasmin-15-100m-Breast.txt', 'Tasmin-15-100m-Free.txt', 'Tasmin-15-200m-Breast.txt']

# %%
help(swim_files.remove)
# Out:
# Help on built-in function remove:
#
# remove(value, /) method of builtins.list instance
#     Remove first occurrence of value.
#
#     Raises ValueError if the value is not present.

# %%
swim_files.remove('.DS_Store')

# %%
len(swim_files)
# Out:
# 60

# %%
import os

# %%
swim_files = os.listdir(swimclub.FOLDER)

# %%
len(swim_files)
# Out:
# 61

# %%
print(swim_files)
# Out:
# ['Hannah-13-100m-Free.txt', 'Darius-13-100m-Back.txt', 'Owen-15-100m-Free.txt', 'Mike-15-100m-Free.txt', 'Hannah-13-100m-Back.txt', 'Mike-15-100m-Back.txt', 'Mike-15-100m-Fly.txt', 'Abi-10-50m-Back.txt', 'Ruth-13-200m-Free.txt', '.DS_Store', 'Tasmin-15-100m-Back.txt', 'Erika-15-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Abi-10-50m-Free.txt', 'Maria-9-50m-Free.txt', 'Elba-14-100m-Free.txt', 'Tasmin-15-100m-Free.txt', 'Abi-10-100m-Back.txt', 'Abi-10-50m-Breast.txt', 'Mike-15-200m-IM.txt', 'Ali-12-100m-Back.txt', 'Ruth-13-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Darius-13-100m-Breast.txt', 'Ruth-13-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Katie-9-100m-Breast.txt', 'Alison-14-100m-Breast.txt', 'Ruth-13-400m-Free.txt', 'Emma-13-100m-Free.txt', 'Calvin-9-50m-Fly.txt', 'Darius-13-100m-Fly.txt', 'Mike-15-200m-Free.txt', 'Emma-13-100m-Breast.txt', 'Tasmin-15-100m-Breast.txt', 'Blake-15-100m-Free.txt', 'Abi-10-100m-Breast.txt', 'Chris-17-100m-Breast.txt', 'Blake-15-100m-Back.txt', 'Bill-18-200m-Back.txt', 'Darius-13-200m-IM.txt', 'Dave-17-100m-Free.txt', 'Alison-14-100m-Free.txt', 'Lizzie-14-100m-Free.txt', 'Katie-9-50m-Fly.txt', 'Katie-9-50m-Breast.txt', 'Katie-9-50m-Back.txt', 'Lizzie-14-100m-Back.txt', 'Tasmin-15-200m-Breast.txt', 'Katie-9-50m-Free.txt', 'Dave-17-200m-Back.txt', 'Erika-15-200m-Breast.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Free.txt', 'Carl-15-100m-Back.txt', 'Bill-18-100m-Back.txt', 'Katie-9-100m-Free.txt', 'Blake-15-100m-Fly.txt', 'Erika-15-100m-Breast.txt', 'Katie-9-100m-Back.txt']

# %%
print(sorted(swim_files))
# Out:
# ['.DS_Store', 'Abi-10-100m-Back.txt', 'Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt', 'Ali-12-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Alison-14-100m-Breast.txt', 'Alison-14-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Bill-18-100m-Back.txt', 'Bill-18-200m-Back.txt', 'Blake-15-100m-Back.txt', 'Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt', 'Carl-15-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Chris-17-100m-Breast.txt', 'Darius-13-100m-Back.txt', 'Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt', 'Dave-17-100m-Free.txt', 'Dave-17-200m-Back.txt', 'Elba-14-100m-Free.txt', 'Emma-13-100m-Breast.txt', 'Emma-13-100m-Free.txt', 'Erika-15-100m-Breast.txt', 'Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt', 'Hannah-13-100m-Back.txt', 'Hannah-13-100m-Free.txt', 'Katie-9-100m-Back.txt', 'Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie-9-50m-Back.txt', 'Katie-9-50m-Breast.txt', 'Katie-9-50m-Fly.txt', 'Katie-9-50m-Free.txt', 'Lizzie-14-100m-Back.txt', 'Lizzie-14-100m-Free.txt', 'Maria-9-50m-Free.txt', 'Mike-15-100m-Back.txt', 'Mike-15-100m-Fly.txt', 'Mike-15-100m-Free.txt', 'Mike-15-200m-Free.txt', 'Mike-15-200m-IM.txt', 'Owen-15-100m-Free.txt', 'Ruth-13-100m-Back.txt', 'Ruth-13-100m-Free.txt', 'Ruth-13-200m-Back.txt', 'Ruth-13-200m-Free.txt', 'Ruth-13-400m-Free.txt', 'Tasmin-15-100m-Back.txt', 'Tasmin-15-100m-Breast.txt', 'Tasmin-15-100m-Free.txt', 'Tasmin-15-200m-Breast.txt']

# %%
swim_files.remove('.DS_Store')

# %%
len(swim_files)
# Out:
# 60

# %%
for file in swim_files:
    print(file)
# Out:
# Hannah-13-100m-Free.txt
# Darius-13-100m-Back.txt
# Owen-15-100m-Free.txt
# Mike-15-100m-Free.txt
# Hannah-13-100m-Back.txt
# Mike-15-100m-Back.txt
# Mike-15-100m-Fly.txt
# Abi-10-50m-Back.txt
# Ruth-13-200m-Free.txt
# Tasmin-15-100m-Back.txt
# Erika-15-100m-Free.txt
# Ruth-13-200m-Back.txt
# Abi-10-50m-Free.txt
# Maria-9-50m-Free.txt
# Elba-14-100m-Free.txt
# Tasmin-15-100m-Free.txt
# Abi-10-100m-Back.txt
# Abi-10-50m-Breast.txt
# Mike-15-200m-IM.txt
# Ali-12-100m-Back.txt
# Ruth-13-100m-Back.txt
# Chris-17-100m-Back.txt
# Ali-12-100m-Free.txt
# Darius-13-100m-Breast.txt
# Ruth-13-100m-Free.txt
# Aurora-13-50m-Free.txt
# Katie-9-100m-Breast.txt
# Alison-14-100m-Breast.txt
# Ruth-13-400m-Free.txt
# Emma-13-100m-Free.txt
# Calvin-9-50m-Fly.txt
# Darius-13-100m-Fly.txt
# Mike-15-200m-Free.txt
# Emma-13-100m-Breast.txt
# Tasmin-15-100m-Breast.txt
# Blake-15-100m-Free.txt
# Abi-10-100m-Breast.txt
# Chris-17-100m-Breast.txt
# Blake-15-100m-Back.txt
# Bill-18-200m-Back.txt
# Darius-13-200m-IM.txt
# Dave-17-100m-Free.txt
# Alison-14-100m-Free.txt
# Lizzie-14-100m-Free.txt
# Katie-9-50m-Fly.txt
# Katie-9-50m-Breast.txt
# Katie-9-50m-Back.txt
# Lizzie-14-100m-Back.txt
# Tasmin-15-200m-Breast.txt
# Katie-9-50m-Free.txt
# Dave-17-200m-Back.txt
# Erika-15-200m-Breast.txt
# Calvin-9-50m-Back.txt
# Calvin-9-50m-Free.txt
# Carl-15-100m-Back.txt
# Bill-18-100m-Back.txt
# Katie-9-100m-Free.txt
# Blake-15-100m-Fly.txt
# Erika-15-100m-Breast.txt
# Katie-9-100m-Back.txt

# %%
for n,file in enumerate(swim_files,1):
    print(n,"file being processed is " + ": " + file)
    swimclub.read_swim_data(file)
# Out:
# file being processed is : Hannah-13-100m-Free.txt
# file being processed is : Darius-13-100m-Back.txt
# file being processed is : Owen-15-100m-Free.txt
# file being processed is : Mike-15-100m-Free.txt
# file being processed is : Hannah-13-100m-Back.txt
# file being processed is : Mike-15-100m-Back.txt
# file being processed is : Mike-15-100m-Fly.txt
# file being processed is : Abi-10-50m-Back.txt
# file being processed is : Ruth-13-200m-Free.txt
# file being processed is : Tasmin-15-100m-Back.txt
# file being processed is : Erika-15-100m-Free.txt
# file being processed is : Ruth-13-200m-Back.txt
# file being processed is : Abi-10-50m-Free.txt
# file being processed is : Maria-9-50m-Free.txt
# file being processed is : Elba-14-100m-Free.txt
# file being processed is : Tasmin-15-100m-Free.txt
# file being processed is : Abi-10-100m-Back.txt
# file being processed is : Abi-10-50m-Breast.txt
# file being processed is : Mike-15-200m-IM.txt
# file being processed is : Ali-12-100m-Back.txt
# file being processed is : Ruth-13-100m-Back.txt
# file being processed is : Chris-17-100m-Back.txt
# file being processed is : Ali-12-100m-Free.txt
# file being processed is : Darius-13-100m-Breast.txt
# file being processed is : Ruth-13-100m-Free.txt
# file being processed is : Aurora-13-50m-Free.txt
# file being processed is : Katie-9-100m-Breast.txt
# file being processed is : Alison-14-100m-Breast.txt
# file being processed is : Ruth-13-400m-Free.txt
# file being processed is : Emma-13-100m-Free.txt
# file being processed is : Calvin-9-50m-Fly.txt
# file being processed is : Darius-13-100m-Fly.txt
# file being processed is : Mike-15-200m-Free.txt
# file being processed is : Emma-13-100m-Breast.txt
# file being processed is : Tasmin-15-100m-Breast.txt
# file being processed is : Blake-15-100m-Free.txt
# file being processed is : Abi-10-100m-Breast.txt
# file being processed is : Chris-17-100m-Breast.txt
# file being processed is : Blake-15-100m-Back.txt
# file being processed is : Bill-18-200m-Back.txt
# file being processed is : Darius-13-200m-IM.txt
# file being processed is : Dave-17-100m-Free.txt
# file being processed is : Alison-14-100m-Free.txt
# file being processed is : Lizzie-14-100m-Free.txt
# file being processed is : Katie-9-50m-Fly.txt
# file being processed is : Katie-9-50m-Breast.txt
# file being processed is : Katie-9-50m-Back.txt
# file being processed is : Lizzie-14-100m-Back.txt
# file being processed is : Tasmin-15-200m-Breast.txt
# file being processed is : Katie-9-50m-Free.txt
# file being processed is : Dave-17-200m-Back.txt
# file being processed is : Erika-15-200m-Breast.txt
# file being processed is : Calvin-9-50m-Back.txt
# file being processed is : Calvin-9-50m-Free.txt
# file being processed is : Carl-15-100m-Back.txt
# file being processed is : Bill-18-100m-Back.txt
# file being processed is : Katie-9-100m-Free.txt
# file being processed is : Blake-15-100m-Fly.txt
# file being processed is : Erika-15-100m-Breast.txt
# file being processed is : Katie-9-100m-Back.txt
