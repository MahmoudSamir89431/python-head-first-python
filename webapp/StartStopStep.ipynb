# %%
fav = "Life, the Universe and Everything"

# %%
fav[0],fav[1]
# Out:
# ('L', 'i')

# %%
fav[-1], fav[-2]
# Out:
# ('g', 'n')

# %%
fav[0:4]
# Out:
# 'Life'

# %%
msg = "My name's Marvin and I am depressed."
msg[::2]
# Out:
# 'M aesMri n  mdpesd'

# %%
msg[:3]
# Out:
# 'My '

# %%
msg[::3]
# Out:
# 'Mne rnnImeee'
